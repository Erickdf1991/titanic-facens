# %% [markdown]
# # **Trabalho Final**
# ### Algoritmos e Programação com Linguagem Python
# ---
#
# **Orientações Gerais:**
#
# * Esta é o trabalho final prático onde serão trabalhados conceitos
# apresentados e exercitados em sala de aula.
#
# * Aspéctos como clareza e organização do código, comentários, raciocínio lógico, coerência no nome de variáveis, utilização das estruturas mais adequadas para a solução dos problemas e o funcionamento adequado serão analisados e irão compor o valor da nota final.
#
# * Procure entender exatamente o que se pede antes de iniciar a codificação. Quando se sabe o que é necessário fazer, a codificação fica mais fácil, mais eficiente e mais divertida ;-).
#
# * Faça o upload do notebook completo nomeado da seguinte forma: *nome_sobrenome_RA.ipynb*.
#
# * No caso de grupos, informar ao professor os membros de cada grupo e cada um deverá importar o arquivo no Canvas individualmente.
#
# * Arquivos com nomes incorretos serão desconsiderados!
#
# * Não deixem dúvidas para trás! Acessem os grupos combinados ou entrem em contato com o professor.
#
# ✌ Sucesso o/

# %% [markdown]
# # RMS Titanic
#
# O RMS Titanic foi um navio de passageiros britânico operado pela White Star Line e construído pelos estaleiros da Harland and Wolff em Belfast. Foi a segunda embarcação da Classe Olympic de transatlânticos depois do RMS Olympic e seguido pelo HMHS Britannic. Projetado pelos engenheiros navais Alexander Carlisle e Thomas Andrews, sua construção começou em março de 1909 e ele foi lançado ao mar em maio de 1911. O Titanic foi pensado para ser o navio mais luxuoso e mais seguro de sua época, gerando lendas que era supostamente "inafundável".
#
# A embarcação partiu em sua viagem inaugural de Southampton para Nova Iorque em 10 de abril de 1912, no caminho passando em Cherbourg-Octeville na França e por Queenstown na Irlanda. Ele colidiu com um iceberg às 23h40min do dia 14 de abril e afundou na madrugada do dia seguinte matando mais de 1500 pessoas, sendo um dos maiores desastres marítimos em tempos de paz de toda a história. Seu naufrágio destacou vários pontos fracos de seu projeto, deficiências nos procedimentos de evacuação de emergência e falhas nas regulamentações marítimas da época. Comissões de inquérito foram instauradas nos Estados Unidos e no Reino Unido, levando a mudanças nas leis internacionais de navegação que permanecem em vigor mais de um século depois.
#
# Os destroços do Titanic foram procurados por décadas até serem encontrados em 1985 por uma equipe liderada por Robert Ballard. Ele se encontra a 3843 m de profundidade e a 650 km ao sudeste de Terra Nova no Canadá. Sua história e naufrágio permaneceram no imaginário popular durante décadas, levando a produção de vários livros e filmes a seu respeito, mais notavelmente o filme Titanic de 1997. Até hoje o Titanic permanece como um dos navios mais famosos da história, com seus destroços atraindo várias expedições de exploração ao longo dos anos.
#
# *Fonte:* [WikiPedia](https://pt.wikipedia.org/wiki/RMS_Titanic)
#
# --------

# %% [markdown]
# A equipe da [Udacity](https://udacity.com) disponibilizou informações sobre uma parte dos passageiros à bordo do RMS Titanic no dia daquela tragédia. Esse _dataset_ que contém informações reais vem sendo utilizado em diversos estudos de caso, além de servir de base para aprendizado de Ciência de Dados, Estatística e Machine Learning.
#
# O arquivo **titanic_data.csv** contém informações reais sobre os passageiros organizadas da seguinte forma:
#
# - Survived (Sobreviveu): 0 = Não, 1 = Sim
# - Pclass (Classe): Classe de ingresso 1 = 1º, 2 = 2º, 3 = 3º
# - Sex (Sexo): Sexo do passageiro
# - Age (Idade): Idade em anos
# - Sibsp: Quantidade de irmãos / cônjuges a bordo do Titanic
# - Parch: Quantidade de pais / crianças a bordo do Titanic
# - Ticket (Bilhete): Número do bilhete de embarque
# - Fare (Tarifa): Tarifa paga pelo Passageiro
# - Cabin (Cabine): Número de cabine
# - Embarked (Embarque): Porto de Embarque (C = Cherbourg, Q = Queenstown, S = Southampton)
#
# O objetivo deste estudo é obter algumas informações estatísticas sobre a tragédia e realizar alguns _insights_ a respeito dos tripulantes e das circunstâncias do acidente.
#
# Efetue a carga do arquivo através da biblioteca _Pandas_ e a partir do _DataFrame_ gerado, efetue as operações necessárias para responder as questões.

# %% [markdown]
# ##imports

# %%
## Importando bibliotecas do Pandas, Numpy e biblioteca para gráficos.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ## Importando o DataSet

# %% [markdown]
# 1 - Efetuar a leitura do dataset através do Pandas, gerando um DataFrame de nome tit, levando-se em consideração que o arquivo encontra-se na mesma pasta do notebook.

# %%
##lendo o arquivo com o pandas
## tit é o DataFrame
tit = pd.read_csv('/content/titanic_data.csv')

# %% [markdown]
# ## Conhecendo o DataSet

# %% [markdown]
# 2 - Quantas linhas e colunas tem o dataset? Quais os tipos das colunas?

# %%
#quantidade de linhas e colunas
tit.shape
# Out:
# (891, 12)

# %%
#tipos de colunas
tit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# 3 - Mostre os dados dos dez primeiros e 8 últimos registros do dataset.

# %%
#mostrando os 10 primeiros registros
tit.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# Mostrando os 8 ultimos registros
tit.tail(8)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket    Fare Cabin Embarked
# 883    male  28.0      0      0  C.A./SOTON 34068  10.500   NaN        S
# 884    male  25.0      0      0   SOTON/OQ 392076   7.050   NaN        S
# ...

# %% [markdown]
# 4 - Cálculos envolvendo colunas numéricas com dados faltantes podem sofrer impacto. É possível afirmar se há dados faltantes no dataset? Caso positivo, quais e quantos seriam esses dados? Preencha os dados faltantes de forma que não influenciem em operações futuras.

# %%
#exibir valores ausentes por colunas
total_faltantes = tit.isna().sum().plot(kind='bar', figsize=(15, 5), color='blue', ylabel='Quantidade')

## O código mostra o total de faltantes em cima do grafico com o label_type"edge"
for linha in total_faltantes.containers:
  total_faltantes.bar_label(linha, label_type="edge", fontsize= 13)

plt.tight_layout()
plt.show()

## Os dados faltantes da coluna Cabine não considerados relevantes para a análise abordada.

# %%
#chamando função com metodo de calculo para preenchimento dos dados ausentes
def definindo_dados_Nan (metodo): 

  if metodo == 1:
    ## Os dados vazios serão deletados.
    tit.dropna(subset=["Age"], axis=0, inplace=True)

  elif metodo == 2:
    ## Os dados vazios da coluna idade foram preenchidos com a Media das idades.
    tit['Age'] = tit['Age'].fillna(int(tit['Age'].mean()))

  elif metodo == 3:
    ## Os dados vazios da coluna idade foram preenchidos com a Mediana das idades.
    tit['Age'] = tit['Age'].fillna(int(tit['Age'].median()))

  elif metodo == 4:
    ## Os dados vazios da coluna idade foram preenchidos com valor random dentro limites em Desvio padrão das idades

    dp = tit['Age'].std()
    dif_Max = tit['Age'].mean() + dp
    dif_Min = tit['Age'].mean() - dp

    total= len(tit.index)

    for n in range(total):
      dado = tit.loc[n,'Age']
      if pd.isnull(dado) == True:
        tit.loc[n,'Age'] = random.randint(int(dif_Min), int(dif_Max))

  elif metodo == 5:
    ## Os dados vazios da coluna idade foram preenchidos com valor random dentro limites Minimo e Maximo das idades

    Max = tit['Age'].max()
    Min = tit['Age'].min()

    total= len(tit.index)

    for n in range(total):
      dado = tit.loc[n,'Age']
      if pd.isnull(dado) == True:
        tit.loc[n,'Age'] = random.randint(int(Min), int(Max))

  else:
    ## Os dados vazios da coluna idade foram preenchidos com a Media das idades.
    tit['Age'] = tit['Age'].fillna(int(tit['Age'].mean()))

  #tit

# %%
print('Escolha método de análise para dados das Idades:')
print('1 - Destrutivo: deleta dados ausentes')
print('2 - Construtivo: preenche dados ausentes com média das Idades - (default)')
print('3 - Construtivo: preenche dados ausentes com mediana das Idades')
print('4 - Construtivo: preenche dados ausentes com valores aleatórios com base Desvio Padrão das Idades')
print('5 - Construtivo: preenche dados ausentes com valores aleatórios com base Mínimo e Máximo das Idades')

metodo = int(input())

definindo_dados_Nan(metodo)
# Out:
# Escolha método de análise para dados das Idades:
# 1 - Destrutivo: deleta dados ausentes
# 2 - Construtivo: preenche dados ausentes com média das Idades - (default)
# 3 - Construtivo: preenche dados ausentes com mediana das Idades
# 4 - Construtivo: preenche dados ausentes com valores aleatórios com base Desvio Padrão das Idades
# 5 - Construtivo: preenche dados ausentes com valores aleatórios com base Mínimo e Máximo das Idades
# 4

# %% [markdown]
# ## Adequando o DataSet

# %% [markdown]
# 5 - Uma vez que algumas colunas não serão utilizadas, eventualmente é melhor excluí-las para que não interfiram na análise. Assim, exclua do dataset as colunas Sibsp, Parch e Ticket.

# %%
#excluíndo as colunas do dataset
tit = tit.drop(columns=['SibSp','Parch','Ticket'])
tit
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age     Fare  \
# 0                              Braund, Mr. Owen Harris    male  22.0   7.2500
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  71.2833
# 2                               Heikkinen, Miss. Laina  female  26.0   7.9250
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1000
# 4                             Allen, Mr. William Henry    male  35.0   8.0500
# ...

# %% [markdown]
# 6 - Renomear as colunas restantes para a lingua portuguesa, utilizando os seguintes nomes de colunas: IdPassageiro, Sobreviveu, Classe, Nome, Sexo, Idade, Tarifa, Cabine e Embarque.

# %%
#renomeando os nomes das colunas
tit = tit.rename(columns={
    
    'PassengerId': 'IdPassageiro',
    'Survived':'Sobreviveu',
    'Pclass':'Classe',
    'Name':'Nome',
    'Sex':'Sexo',
    'Age':'Idade',
    'Fare':'Tarifa',
    'Cabin':'Cabine',
    'Embarked':'Embarque'

})

tit
# Out:
#      IdPassageiro  Sobreviveu  Classe  \
# 0               1           0       3
# 1               2           1       1
# 2               3           1       3
# 3               4           1       1
# 4               5           0       3
# ..            ...         ...     ...
# 886           887           0       2
# 887           888           1       1
# 888           889           0       3
# 889           890           1       1
# 890           891           0       3
#
#                                                   Nome    Sexo  Idade  \
# 0                              Braund, Mr. Owen Harris    male   22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 2                               Heikkinen, Miss. Laina  female   26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 4                             Allen, Mr. William Henry    male   35.0
# ..                                                 ...     ...    ...
# ...

# %% [markdown]
# 7 - Alterar o conteudo da coluna Sobreviveu para:
# - 0 => Não
# - 1 => Sim

# %%
#substituindo as informações da coluna Sobreviveu
tit['Sobreviveu'] = tit['Sobreviveu'].replace({0: 'Não', 1: 'Sim'})
tit
# Out:
#      IdPassageiro Sobreviveu  Classe  \
# 0               1        Não       3
# 1               2        Sim       1
# 2               3        Sim       3
# 3               4        Sim       1
# 4               5        Não       3
# ..            ...        ...     ...
# 886           887        Não       2
# 887           888        Sim       1
# 888           889        Não       3
# 889           890        Sim       1
# 890           891        Não       3
#
#                                                   Nome    Sexo  Idade  \
# 0                              Braund, Mr. Owen Harris    male   22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 2                               Heikkinen, Miss. Laina  female   26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 4                             Allen, Mr. William Henry    male   35.0
# ..                                                 ...     ...    ...
# ...

# %% [markdown]
# 8 - Alterar o conteudo da coluna Sexo para:
# - female => Mulher
# - male   => Homem

# %%
#substituindo as informações de Sexo
tit['Sexo'] = tit['Sexo'].replace({'female': 'Mulher', 'male': 'Homem'})
tit
# Out:
#      IdPassageiro Sobreviveu  Classe  \
# 0               1        Não       3
# 1               2        Sim       1
# 2               3        Sim       3
# 3               4        Sim       1
# 4               5        Não       3
# ..            ...        ...     ...
# 886           887        Não       2
# 887           888        Sim       1
# 888           889        Não       3
# 889           890        Sim       1
# 890           891        Não       3
#
#                                                   Nome    Sexo  Idade  \
# 0                              Braund, Mr. Owen Harris   Homem   22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  Mulher   38.0
# 2                               Heikkinen, Miss. Laina  Mulher   26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  Mulher   35.0
# 4                             Allen, Mr. William Henry   Homem   35.0
# ..                                                 ...     ...    ...
# ...

# %% [markdown]
# ## Alguns números

# %% [markdown]
# 9 - Quantas mulheres e quantos homems estavam à bordo, de acordo com o dataset?

# %%
#realiza filtro e calculo das mulheres e homens 
Mulher = tit[tit['Sexo'] == 'Mulher']
Mulher = Mulher['Sexo'].value_counts()

Homem = tit[tit['Sexo'] == 'Homem']
Homem = Homem['Sexo'].value_counts()

pessoas = pd.Series([int(Mulher), int(Homem)], ['Mulher', 'Homem'])

pessoas = pessoas.head(20).plot(kind='barh', figsize=(20, 6), color='darkblue', xlabel='Quantidade')

for linha in pessoas.containers:
  pessoas.bar_label(linha, label_type="edge", fontsize= 13)


plt.tight_layout()
plt.show()

# %% [markdown]
# 10 - Quantos passageiros sobreviveram e quantos não sobreviveram?

# %%
#realiza filtro dos passageiros 
qtdSob = tit[tit['Sobreviveu'] == 'Sim']
qtdSob = qtdSob['Sobreviveu'].value_counts()
 
qtdNSob = tit[tit['Sobreviveu'] == 'Não']
qtdNSob = qtdNSob['Sobreviveu'].value_counts()

viajantes = pd.Series([int(qtdSob), int(qtdNSob)], ['Sobreviventes', 'Mortos'])

viajantes = viajantes.head(20).plot(kind='bar', figsize=(15, 5), color='lightblue', ylabel='Quantidade')

for linha in viajantes.containers:
  viajantes.bar_label(linha, label_type="edge", fontsize= 13)

plt.tight_layout()
plt.show()

# %% [markdown]
# 11 - Quantas mulheres não sobreviveram?

# %%
#realiza filtro das mulheres não sobreviveram
Mulher_NSob = tit[
    (tit['Sexo'] == 'Mulher') & (tit['Sobreviveu'] == 'Não')
]     

Mulher_NSob = Mulher_NSob['Sexo'].value_counts()
print(f'Sobreviveram {int(Mulher_NSob)} mulheres.')

Mulher_NSob.plot(kind='barh', figsize=(15, 4), color='orange', xlabel='Quantidade')
# Out:
# Sobreviveram 81 mulheres.
# <Axes: xlabel='Quantidade'>

# %% [markdown]
# 12 - Proporcionalmente, sobreviveram mais homens ou mais mulheres? Cite as proporções.

# %%
#realiza filtro e calculo proporcional das mulheres e homens sobreviveram
Mulher_Sob = tit[
    (tit['Sexo'] == 'Mulher') & (tit['Sobreviveu'] == 'Sim')
]     
Mulher_Sob = Mulher_Sob['Sexo'].value_counts()
Mulher_Sob
Pct_Mulher = Mulher_Sob/Mulher *100

Homem_Sob = tit[
    (tit['Sexo'] == 'Homem') & (tit['Sobreviveu'] == 'Sim')
]     
Homem_Sob = Homem_Sob['Sexo'].value_counts()
Homem_Sob
Pct_Homem = Homem_Sob/Homem *100

Pct_Mulher, Pct_Homem

#print(f'Proporcionalmente sobreviveram mais mulheres: {round(float(Pct_Mulher), 2)}%, vs {round(float(Pct_Homem), 2)}% de homens.')


PctMH = pd.Series([int(Pct_Mulher), int(Pct_Homem)], ['Mulheres', 'Homens'])

PctMH = PctMH.head(20).plot(kind='bar', figsize=(15, 5), color='lightgreen',ylabel='Percentual de Sobreviventes - %')

for linha in PctMH.containers:
  PctMH.bar_label(linha, label_type="edge", fontsize= 13)

plt.tight_layout()
plt.show()

# %% [markdown]
# 13 - Levando-se em consideração a idade dos passageiros, qual a idade e quantidade de pessoas com o maior número de mortos?

# %%
#realiza filtro da idade e quantidade de pessoas com maior número de mortos
resultado = tit[
    (tit['Sobreviveu'] == 'Não')
]
resultado = resultado['Idade'].value_counts()

resultado = resultado.head(20).plot(kind='bar', figsize=(20, 6), color='red', ylabel='Número de Mortos', xlabel='Idade')

for linha in resultado.containers:
  resultado.bar_label(linha, label_type="edge", fontsize= 13)

plt.tight_layout()
plt.show()

# %% [markdown]
# 14 - Qual a média de idade dos homens sobreviventes?

# %%
#realiza filtro e calculo da média dos homens sobreviventes
Idd_media_HSob = tit[
    (tit['Sexo'] == 'Homem') & (tit['Sobreviveu'] == 'Sim')
]   
 
idade_media_homens = Idd_media_HSob['Idade'].mean()
idade_max = Idd_media_HSob['Idade'].max()
idade_min = Idd_media_HSob['Idade'].min()

idade = {'idade minima':[idade_min],
       'idade media':[idade_media_homens],
       'idade maxima': [idade_max]
       }
dfidade = pd.DataFrame(idade)


dfidade.plot(kind='box', vert=True, figsize=(15, 4), color='blue', ylabel='Idade em Anos')



print(f'A idade média dos homens sobreviventes foi de {round(int(idade_media_homens),)} anos')
# Out:
# A idade média dos homens sobreviventes foi de 27 anos

# %% [markdown]
# 15 - Levando-se em consideração passageiros prioritários (mulheres e crianças de até 15 anos independente do sexo) qual a proporção de sobreviventes por sexo?

# %%
#realiza filtro e calculo da proporção considerando passageiros prioritários
CrH = tit[
    (tit['Sexo'] == 'Homem') & (tit['Sobreviveu'] == 'Sim') & (tit['Idade'] <= 15)
]
 
CrM = tit[
    (tit['Sexo'] == 'Mulher') & (tit['Sobreviveu'] == 'Sim') & (tit['Idade'] <= 15)
]

 
C_Male = CrH['Sexo'].value_counts()
C_Female = CrM['Sexo'].value_counts()

Mulher_maior15 = int(Mulher) - int(C_Female)
Total_PP = int(Mulher_maior15) + int(C_Male) + int(C_Female)
Total_PP


Prop_PP_F = round((int(Mulher_maior15) + int(C_Female)) / int(Total_PP) * 100, 2)
Prop_PP_M = round(int(C_Male) / int(Total_PP) * 100, 2)
 
Prop_PP_F, Prop_PP_M

# Fonte para o gráfico de pizza: https://medium.com/horadecodar/gr%C3%A1ficos-de-pizza-com-matplotlib-piechart-33ea9760ad87

labels = 'Feminino Prioritário', 'Masculino Prioritário'
sizes = [round(float(Prop_PP_F),2), round(float(Prop_PP_M),2)]

fig1, ax1 = plt.subplots()

ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')

plt.show()

# %% [markdown]
# 16 - Qual a quantidade de passageiros por classe?

# %%
#realiza filtro da quantidade de passageiros pelo número da classe
contagem = tit['Classe'].value_counts()


contagem = contagem.head(20).plot(kind='bar', figsize=(15, 5), color='purple',ylabel='Quantidade de Passageiros',xlabel='Número da Classe')

for linha in contagem.containers:
  contagem.bar_label(linha, label_type="edge", fontsize= 13)

plt.tight_layout()
plt.show()

# %% [markdown]
# 17 - Qual o percentual de sobreviventes por classe?

# %%
#realiza filtro e calculo do percentual de sobreviventes por classe de sobreviventes das classes
#realiza filtro e calculo do percentual de sobreviventes por classe com base em todos sobreviventes das classes

TClasse1 = tit[
    (tit['Classe'] == 1) & (tit['Sobreviveu'])
]

TClasse1 = TClasse1['Classe'].value_counts() 

Classe_1 = tit[
    (tit['Classe'] == 1) & (tit['Sobreviveu'] == 'Sim')
]
Classe_1 = Classe_1['Classe'].value_counts() 

PP_Classe_1 = Classe_1 / TClasse1 *100


TClasse2 = tit[
    (tit['Classe'] == 2) & (tit['Sobreviveu'])
]

TClasse2 = TClasse2['Classe'].value_counts() 

Classe_2 = tit[
    (tit['Classe'] == 2) & (tit['Sobreviveu'] == 'Sim')
]
Classe_2 = Classe_2['Classe'].value_counts() 

PP_Classe_2 = Classe_2 / TClasse2 *100


TClasse3 = tit[
    (tit['Classe'] == 3) & (tit['Sobreviveu'])
]

TClasse3 = TClasse3['Classe'].value_counts() 

Classe_3 = tit[
    (tit['Classe'] == 3) & (tit['Sobreviveu'] == 'Sim')
]
Classe_3 = Classe_3['Classe'].value_counts() 

PP_Classe_3 = Classe_3 / TClasse3 *100



print('Percentual de sobreviventes por classe de sobreviventes')
PctPClasse = pd.Series([int(PP_Classe_1), int(PP_Classe_2), int(PP_Classe_3)], ['Classe 1', 'Classe 2', 'Classe 3'])

PctPClasse = PctPClasse.head(20).plot(kind='bar', figsize=(15, 5), color='orange',ylabel='Percentual de Sobreviventes por Classe')

for linha in PctPClasse.containers:
  PctPClasse.bar_label(linha, label_type="edge", fontsize= 13)

plt.tight_layout()
plt.show()

print()
print()

print('Percentual de sobreviventes por classe com base em todas as classes')
labels_1 = '% Sobr_Classe 1 / Total_Sobr', '% Sobr_Classe 2 / Total_Sobr', '% Sobr_Classe 3 / Total_Sobr'
sizes_1 = [round(float(Classe_1),2), round(float(Classe_2),2), round(float(Classe_3),2)]

fig1, ax1 = plt.subplots()

ax1.pie(sizes_1, labels=labels_1, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')

plt.show()
# Out:
# Percentual de sobreviventes por classe de sobreviventes
# Percentual de sobreviventes por classe com base em todas as classes

# %% [markdown]
# 18 - Crie um dataframe que demonstre a quantidade de sobreviventes e não sobreviventes, agrupados por sexo e classe.

# %%
#realiza filtro da quantidade de sobreviventes e não sobreviventes agrupados por sexo e classe

#Homens sobreviventes
HS1 = tit[
    (tit['Sexo'] == 'Homem') & (tit['Sobreviveu'] == 'Sim') & (tit['Classe'] == 1)
]
HS1 = HS1['Sexo'].value_counts()


HS2 = tit[
    (tit['Sexo'] == 'Homem') & (tit['Sobreviveu'] == 'Sim') & (tit['Classe'] == 2)
]
HS2 = HS2['Sexo'].value_counts()


HS3 = tit[
    (tit['Sexo'] == 'Homem') & (tit['Sobreviveu'] == 'Sim') & (tit['Classe'] == 3)
]
HS3 = HS3['Sexo'].value_counts()


#Homens não sobreviventes
HN1 = tit[
    (tit['Sexo'] == 'Homem') & (tit['Sobreviveu'] == 'Não') & (tit['Classe'] == 1)
]
HN1 = HN1['Sexo'].value_counts()


HN2 = tit[
    (tit['Sexo'] == 'Homem') & (tit['Sobreviveu'] == 'Não') & (tit['Classe'] == 2)
]
HN2 = HN2['Sexo'].value_counts()


HN3 = tit[
    (tit['Sexo'] == 'Homem') & (tit['Sobreviveu'] == 'Não') & (tit['Classe'] == 3)
]
HN3 = HN3['Sexo'].value_counts()



##Mulheres sobreviventes
MS1 = tit[
    (tit['Sexo'] == 'Mulher') & (tit['Sobreviveu'] == 'Sim') & (tit['Classe'] == 1)
]
MS1 = MS1['Sexo'].value_counts()


MS2 = tit[
    (tit['Sexo'] == 'Mulher') & (tit['Sobreviveu'] == 'Sim') & (tit['Classe'] == 2)
]
MS2 = MS2['Sexo'].value_counts()


MS3 = tit[
    (tit['Sexo'] == 'Mulher') & (tit['Sobreviveu'] == 'Sim') & (tit['Classe'] == 3)
]
MS3 = MS3['Sexo'].value_counts()


#Mulheres não sobreviventes
MN1 = tit[
    (tit['Sexo'] == 'Mulher') & (tit['Sobreviveu'] == 'Não') & (tit['Classe'] == 1)
]
MN1 = MN1['Sexo'].value_counts()


MN2 = tit[
    (tit['Sexo'] == 'Mulher') & (tit['Sobreviveu'] == 'Não') & (tit['Classe'] == 2)
]
MN2 = MN2['Sexo'].value_counts()


MN3 = tit[
    (tit['Sexo'] == 'Mulher') & (tit['Sobreviveu'] == 'Não') & (tit['Classe'] == 3)
]
MN3 = MN3['Sexo'].value_counts()

    


data = {
    'Sexo': ['Masculino', 'Masculino', 'Masculino', 'Feminino', 'Feminino', 'Feminino'],
    'Classe': ['1ª Classe', '2ª Classe', '3ª Classe', '1ª Classe', '2ª Classe', '3ª Classe'],
    'Sobreviveu': [int(HS1), int(HS2), int(HS3), int(MS1), int(MS2), int(MS3)]
}

# transformando o dicionário em um dataframe
df100 = pd.DataFrame(data)

df100['Não Sobreviveu'] = [int(HN1), int(HN2), int(HN3), int(MN1), int(MN2), int(MN3)]


# exibindo o dataframe
display(df100)
# Out:
#         Sexo     Classe  Sobreviveu  Não Sobreviveu
# 0  Masculino  1ª Classe          45              77
# 1  Masculino  2ª Classe          17              91
# 2  Masculino  3ª Classe          47             300
# 3   Feminino  1ª Classe          91               3
# 4   Feminino  2ª Classe          70               6
# 5   Feminino  3ª Classe          72              72
